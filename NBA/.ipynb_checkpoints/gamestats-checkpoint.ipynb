# %%
import pandas as pd

from nba_api.stats.static import teams
from nba_api.stats.endpoints import leaguegamefinder
from nba_api.stats.library.parameters import Season
from nba_api.stats.library.parameters import SeasonType
from nba_api.live.nba.endpoints import boxscore

# %%
# Data Sets for
# box = boxscore.BoxScore(game_id)
# ---------------------------------
#box.game.get_dict()                    #equal to box.get_dict()['game']
#box.arena.get_dict()                  #equal to box.get_dict()['game']['arena']
#box.away_team.get_dict()              #equal to box.get_dict()['game']['awayTeam']
#box.away_team_player_stats.get_dict() #equal to box.get_dict()['game']['awayTeam']['players']
#box.away_team_stats.get_dict()        #equal to box.get_dict()['game']['homeTeam'] w/o ['players']
#box.home_team.get_dict()              #equal to box.get_dict()['game']['homeTeam']
#box.home_team_player_stats.get_dict() #equal to box.get_dict()['game']['homeTeam']['players']
#box.home_team_stats.get_dict()        #equal to box.get_dict()['game']['homeTeam'] w/o ['players']
#box.game_details.get_dict()           #equal to box.get_dict()['game'] scrubbed of all other dictionaries
#box.officials.get_dict()              #equal to box.get_dict()['game']['officials']

# %%
# DO NOT TOUCH

#result = leaguegamefinder.LeagueGameFinder()
#all_games = result.get_data_frames()[0]

# DO NOT TOUCH

# %%
def boxpuller(homeTeam, date):

    stupid=date.split('-')
    stupidDate = stupid[1]+'/'+stupid[2]+'/'+stupid[0]
    
    nba_teams = teams.get_teams()

    teamA = [team for team in nba_teams if team['abbreviation'] == homeTeam][0]
    teamA_id = teamA['id']


    gamefinder = leaguegamefinder.LeagueGameFinder(team_id_nullable=teamA_id,
                                                   date_from_nullable=stupidDate,
                                                   date_to_nullable=stupidDate)  
    
    game = gamefinder.get_data_frames()[0].sort_values('GAME_DATE').iloc[-1]
    
    game_id = game.GAME_ID
    matchup = game.MATCHUP
        
    # Find the game_id we want
    full_game = all_games[all_games.GAME_ID == game_id]
    
    awayTeam = game.MATCHUP.split()[2]
    print(f'Getting boxscore for {matchup} on {date}')
    
    box = boxscore.BoxScore(game_id)
    
    all_player_stats = []
    
    ht_stats = box.home_team_player_stats.get_dict()
    for player in ht_stats:
        if player['status'] == 'ACTIVE':
            player_stats = player['statistics']
            player_stats.update({"NAME": player['name'],"TEAM":homeTeam, "OPP":awayTeam, "DATE":date})
            all_player_stats.append(player_stats)
            
    at_stats = box.away_team_player_stats.get_dict()
    for player in at_stats:
        if player['status'] == 'ACTIVE':
            player_stats = player['statistics']
            player_stats.update({"NAME": player['name'],"TEAM":awayTeam, "OPP":homeTeam, "DATE":date})
            all_player_stats.append(player_stats)
                
    
    return (full_game, all_player_stats)

# %%
def get_all_stats(games):
    
    
    gameLogPlayerStats = []
    boxes=pd.DataFrame()

    for team,date in games:
        print(team,date)
        boxInfo, gamePlayerStats = boxpuller(team,date)
        boxes = pd.concat([boxes,boxInfo], ignore_index=True)
        for playerStats in gamePlayerStats:
            gameLogPlayerStats.append(playerStats)


    all_stats = pd.DataFrame(gameLogPlayerStats)
    all_stats = all_stats.drop(columns=['blocksReceived', 'foulsOffensive','foulsDrawn','minus',
                        'plus','plusMinusPoints','pointsFastBreak','pointsInThePaint','pointsSecondChance',
                             'twoPointersAttempted','twoPointersMade','twoPointersPercentage',
                         'threePointersPercentage','freeThrowsPercentage'])

    all_stats = all_stats[['NAME','TEAM','DATE','OPP', 'minutesCalculated', 'points','reboundsTotal','assists','steals','blocks',
     'fieldGoalsMade', 'fieldGoalsAttempted', 'fieldGoalsPercentage',
     'threePointersMade', 'threePointersAttempted',
     'freeThrowsMade', 'freeThrowsAttempted',
     'reboundsDefensive','reboundsOffensive',
     'turnovers',
     'foulsPersonal', 'foulsTechnical']]

    all_stats = all_stats.rename(columns={"minutesCalculated": "MINS", "points": "PTS", "reboundsTotal": "REB",
                           "assists": "AST","steals": "STL","blocks": "BLK",
                            "fieldGoalsMade": "FGM", "fieldGoalsAttempted": "FGA", "fieldGoalsPercentage": "FG%",
                           "threePointersMade": "3PM", "threePointersAttempted": "3PA",
                           "freeThrowsMade": "FTM", "freeThrowsAttempted": "FTA",
                            "reboundsDefensive":"dREB", "reboundsOffensive":"oREB","turnovers":"TO",
                           "foulsPersonal":"FLS", "foulsTechnical":"TFL"})

    all_stats = all_stats.round({'FG%': 2})
    all_stats['MINS'] = all_stats['MINS'].str.replace(r'PT', '')
    all_stats['MINS'] = all_stats['MINS'].str.replace(r'M', '')
    all_stats = all_stats[all_stats['MINS'] != '00']
    all_stats['G'] = 1
    
    return (boxes, all_stats)

# %%
gameLog = [('PHI','2009-02-07'),
          ('WAS','2017-02-13'),
          ('OKC','2017-04-04'),
          ('DEN','2017-04-09'),
          ('GSW','2018-02-24'),
          ('SAC','2018-11-19'),
          ('GSW','2018-11-21')]

gameLog2 = [('GSW','2019-11-25'),
          ('SAC','2019-12-11'),
          ('BKN','2020-01-07'),
          ('HOU','2020-01-15'),
          ('HOU','2020-01-20'),
          ('PHI','2021-04-26'),
          ('WAS','2021-05-29'),
          ('LAC','2021-11-01'),
          ('LAL','2021-11-02'),
          ('LAL','2021-11-04'),
          ('OKC','2021-11-12'),
          ('LAL','2023-02-07'),
          ('PHX','2023-02-24'),
          ('LAC','2023-03-18'),
          ('LAC','2023-03-21')]

# %%
boxScores, all_stats = get_all_stats(gameLog2)
# Out:
# GSW 2019-11-25
# Getting boxscore for GSW vs. OKC on 2019-11-25
# SAC 2019-12-11
# Getting boxscore for SAC vs. OKC on 2019-12-11
# BKN 2020-01-07
# Getting boxscore for BKN vs. OKC on 2020-01-07
# HOU 2020-01-15
# Getting boxscore for HOU vs. POR on 2020-01-15
# HOU 2020-01-20
# Getting boxscore for HOU vs. OKC on 2020-01-20
# PHI 2021-04-26
# Getting boxscore for PHI vs. OKC on 2021-04-26
# WAS 2021-05-29
# Getting boxscore for WAS vs. PHI on 2021-05-29
# LAC 2021-11-01
# Getting boxscore for LAC vs. OKC on 2021-11-01
# LAL 2021-11-02
# Getting boxscore for LAL vs. HOU on 2021-11-02
# LAL 2021-11-04
# Getting boxscore for LAL vs. OKC on 2021-11-04
# OKC 2021-11-12
# Getting boxscore for OKC vs. SAC on 2021-11-12
# LAL 2023-02-07
# Getting boxscore for LAL vs. OKC on 2023-02-07
# PHX 2023-02-24
# Getting boxscore for PHX vs. OKC on 2023-02-24
# LAC 2023-03-18
# Getting boxscore for LAC vs. ORL on 2023-03-18
# LAC 2023-03-21
# Getting boxscore for LAC vs. OKC on 2023-03-21

# %%
boxScores
# Out:
#    SEASON_ID     TEAM_ID TEAM_ABBREVIATION               TEAM_NAME  \
# 0      22019  1610612760               OKC   Oklahoma City Thunder
# 1      22019  1610612744               GSW   Golden State Warriors
# 2      22019  1610612758               SAC        Sacramento Kings
# 3      22019  1610612760               OKC   Oklahoma City Thunder
# 4      22019  1610612751               BKN           Brooklyn Nets
# 5      22019  1610612760               OKC   Oklahoma City Thunder
# 6      22019  1610612745               HOU         Houston Rockets
# 7      22019  1610612757               POR  Portland Trail Blazers
# 8      22019  1610612745               HOU         Houston Rockets
# 9      22019  1610612760               OKC   Oklahoma City Thunder
# 10     22020  1610612755               PHI      Philadelphia 76ers
# 11     22020  1610612760               OKC   Oklahoma City Thunder
# 12     42020  1610612764               WAS      Washington Wizards
# 13     42020  1610612755               PHI      Philadelphia 76ers
# 14     22021  1610612746               LAC             LA Clippers
# 15     22021  1610612760               OKC   Oklahoma City Thunder
# 16     22021  1610612747               LAL      Los Angeles Lakers
# 17     22021  1610612745               HOU         Houston Rockets
# 18     22021  1610612760               OKC   Oklahoma City Thunder
# 19     22021  1610612747               LAL      Los Angeles Lakers
# 20     22021  1610612758               SAC        Sacramento Kings
# 21     22021  1610612760               OKC   Oklahoma City Thunder
# 22     22022  1610612760               OKC   Oklahoma City Thunder
# 23     22022  1610612747               LAL      Los Angeles Lakers
# 24     22022  1610612760               OKC   Oklahoma City Thunder
# 25     22022  1610612756               PHX            Phoenix Suns
# 26     22022  1610612753               ORL           Orlando Magic
# 27     22022  1610612746               LAC             LA Clippers
# 28     22022  1610612746               LAC             LA Clippers
# 29     22022  1610612760               OKC   Oklahoma City Thunder
#
#        GAME_ID   GAME_DATE      MATCHUP WL  MIN  PTS  ...  FT_PCT  OREB  DREB  \
# 0   0021900250  2019-11-25    OKC @ GSW  W  241  100  ...   0.818     9    34
# 1   0021900250  2019-11-25  GSW vs. OKC  L  239   97  ...   0.875     9    32
# 2   0021900365  2019-12-11  SAC vs. OKC  W  238   94  ...   0.600     6    35
# 3   0021900365  2019-12-11    OKC @ SAC  L  240   93  ...   0.667     7    36
# 4   0021900550  2020-01-07  BKN vs. OKC  L  264  103  ...   0.750    11    41
# 5   0021900550  2020-01-07    OKC @ BKN  W  266  111  ...   0.828     8    43
# 6   0021900611  2020-01-15  HOU vs. POR  L  240  107  ...   0.652    12    38
# 7   0021900611  2020-01-15    POR @ HOU  W  240  117  ...   0.828    12    46
# 8   0021900645  2020-01-20  HOU vs. OKC  L  240  107  ...   0.706     9    34
# 9   0021900645  2020-01-20    OKC @ HOU  W  240  112  ...   0.769     7    40
# 10  0022000918  2021-04-26  PHI vs. OKC  W  241  121  ...   0.722    10    31
# 11  0022000918  2021-04-26    OKC @ PHI  L  240   90  ...   0.565    11    27
# 12  0042000103  2021-05-29  WAS vs. PHI  L  239  103  ...   0.760    13    28
# 13  0042000103  2021-05-29    PHI @ WAS  W  240  132  ...   0.650     7    44
# 14  0022100102  2021-11-01  LAC vs. OKC  W  239   99  ...   0.737    13    38
# 15  0022100102  2021-11-01    OKC @ LAC  L  240   94  ...   0.813    10    41
# 16  0022100107  2021-11-02  LAL vs. HOU  W  240  119  ...   0.750    11    32
# 17  0022100107  2021-11-02    HOU @ LAL  L  240  117  ...   0.417    11    27
# 18  0022100123  2021-11-04    OKC @ LAL  W  240  107  ...   0.692    12    38
# 19  0022100123  2021-11-04  LAL vs. OKC  L  240  104  ...   0.824    16    33
# 20  0022100180  2021-11-12    SAC @ OKC  L  239  103  ...   0.765    11    38
# 21  0022100180  2021-11-12  OKC vs. SAC  W  240  105  ...   0.733    16    36
# 22  0022200821  2023-02-07    OKC @ LAL  W  241  133  ...   0.900     7    30
# 23  0022200821  2023-02-07  LAL vs. OKC  L  240  130  ...   0.692     6    35
# 24  0022200899  2023-02-24    OKC @ PHX  L  241  115  ...   0.750    14    33
# 25  0022200899  2023-02-24  PHX vs. OKC  W  240  124  ...   0.813    15    39
# 26  0022201056  2023-03-18    ORL @ LAC  W  240  113  ...   0.760     9    36
# 27  0022201056  2023-03-18  LAC vs. ORL  L  240  108  ...   0.750    13    30
# 28  0022201082  2023-03-21  LAC vs. OKC  L  239  100  ...   0.571    12    34
# 29  0022201082  2023-03-21    OKC @ LAC  W  239  101  ...   0.929    12    35
#
#     REB  AST  STL  BLK  TOV  PF  PLUS_MINUS
# 0    43   26    5   13   15  16         3.0
# 1    41   27   10    7   12  17        -3.0
# 2    41   12    8    3   15  21         1.0
# 3    43   24    8    8   15  16        -1.0
# 4    52   19    5    5   17  25        -8.0
# 5    51   19   11    3   15  15         8.0
# 6    50   24    4    4   12  22       -10.0
# 7    58   22    6    4    7  19        10.0
# 8    43   21    6    7   11  23        -5.0
# 9    47   14    8    6   12  18         5.0
# 10   41   27   22    7   20  19        31.0
# 11   38   21   11    1   29  16       -31.0
# 12   41   18    5    3    8  18       -29.0
# 13   51   31    7    5   15  25        29.0
# 14   51   18    8    5   12  14         5.0
# 15   51   17    8    6   16  18        -5.0
# 16   43   26   10    4   17  19         2.0
# 17   38   27    8    4   24  21        -2.0
# 18   50   23    7    2   16  16         3.0
# 19   49   22    8    5   13  21        -3.0
# 20   49   20    5    7   13  12        -2.0
# 21   52   13    8    6   10  18         2.0
# 22   37   32   12    2   12  18         3.0
# 23   41   27    8    3   20  19        -3.0
# 24   47   27    5    2    9  21        -9.0
# 25   54   23    5    5   11  22         9.0
# 26   45   23   14    5   17  22         5.0
# 27   43   23    9    3   15  24        -5.0
# 28   46   21    9    2   13  21        -1.0
# 29   47   19    2    4   11  21         1.0
#
# [30 rows x 28 columns]

# %%
statlines = all_stats.copy()
statlines = statlines.astype({'MINS': 'int'})
ballers = statlines.groupby('NAME').sum(numeric_only=True).reset_index()
for i in range(len(ballers)):
    if ballers.at[i,'FGM'] > 0:
        ballers.at[i,'FG%'] = round((ballers.at[i,'FGM'] / ballers.at[i,'FGA'])*100,1)
    else:
        ballers.at[i,'FG%'] = 0

# %%
statlines
# Out:
#                     NAME TEAM        DATE  OPP  MINS  PTS  REB  AST  STL  BLK  \
# 0     Glenn Robinson III  GSW  2019-11-25  OKC    36   25    2    5    2    1
# 1          Eric Paschall  GSW  2019-11-25  OKC    32   13   10    1    0    1
# 2    Willie Cauley-Stein  GSW  2019-11-25  OKC    29    4    6    1    2    0
# 3             Alec Burks  GSW  2019-11-25  OKC    33    7    4    3    1    0
# 4              Ky Bowman  GSW  2019-11-25  OKC    39   24    3    5    3    1
# ..                   ...  ...         ...  ...   ...  ...  ...  ...  ...  ...
# 374         Olivier Sarr  OKC  2023-03-21  LAC    19    4    6    2    0    2
# 375           Isaiah Joe  OKC  2023-03-21  LAC    27   12    3    0    1    1
# 376     Lindy Waters III  OKC  2023-03-21  LAC    12    3    2    0    0    0
# 377        Ousmane Dieng  OKC  2023-03-21  LAC     8    3    1    1    0    0
# 378        Aaron Wiggins  OKC  2023-03-21  LAC    20    2    6    1    0    0
#
#      ...  3PM  3PA  FTM  FTA  dREB  oREB  TO  FLS  TFL  G
# 0    ...    3    4    4    5     1     1   1    1    0  1
# 1    ...    0    0    1    1     8     2   5    5    0  1
# 2    ...    0    0    0    0     4     2   0    3    0  1
# 3    ...    1    4    0    0     4     0   3    1    0  1
# 4    ...    2    3    4    4     1     2   1    3    0  1
# ..   ...  ...  ...  ...  ...   ...   ...  ..  ...  ... ..
# 374  ...    0    1    2    2     2     4   2    3    0  1
# 375  ...    2    8    0    0     1     2   0    1    0  1
# 376  ...    1    3    0    0     2     0   1    1    0  1
# 377  ...    1    3    0    0     1     0   0    0    0  1
# 378  ...    0    0    0    0     5     1   0    2    0  1
#
# [303 rows x 23 columns]

# %%
statlines.dtypes
# Out:
# NAME     object
# TEAM     object
# DATE     object
# OPP      object
# MINS      int64
# PTS       int64
# REB       int64
# AST       int64
# STL       int64
# BLK       int64
# FGM       int64
# FGA       int64
# FG%     float64
# 3PM       int64
# 3PA       int64
# FTM       int64
# FTA       int64
# dREB      int64
# oREB      int64
# TO        int64
# FLS       int64
# TFL       int64
# G         int64
# dtype: object

# %%
ballers
# Out:
#                     NAME  MINS  PTS  REB  AST  STL  BLK  FGM  FGA   FG%  3PM  \
# 0          Aaron Wiggins    61   11   10    2    1    2    5   12  41.7    1
# 1            Abdel Nader    60   24    5    2    4    0    9   17  52.9    6
# 2             Alec Burks    33    7    4    3    1    0    3   17  17.6    1
# 3     Aleksej Pokusevski    71   18   17    8    3    3    7   26  26.9    2
# 4               Alex Len    11    2    2    1    0    0    1    3  33.3    0
# ..                   ...   ...  ...  ...  ...  ...  ...  ...  ...   ...  ...
# 160      Wayne Ellington     9    3    2    1    0    0    1    6  16.7    1
# 161   Wendell Carter Jr.    33   27   12    2    3    2   11   19  57.9    4
# 162  Willie Cauley-Stein    29    4    6    1    2    0    2    7  28.6    0
# 163      Wilson Chandler    16    2    4    0    0    1    1    3  33.3    0
# 164         Yogi Ferrell    15    6    1    0    2    0    2    4  50.0    0
#
#      3PA  FTM  FTA  dREB  oREB  TO  FLS  TFL  G
# 0      2    0    0     9     1   3    9    0  3
# 1     10    0    0     4     1   3    6    0  3
# 2      4    0    0     4     0   3    1    0  1
# 3     11    2    4    13     4   7    2    0  4
# 4      0    0    0     1     1   0    1    0  1
# ..   ...  ...  ...   ...   ...  ..  ...  ... ..
# 160    5    0    0     1     1   0    0    0  1
# 161    8    1    1    10     2   3    2    0  1
# 162    0    0    0     4     2   0    3    0  1
# 163    2    0    0     4     0   2    3    0  1
# 164    1    2    2     1     0   1    0    0  1
#
# [165 rows x 20 columns]

# %%
tripdubs = statlines.loc[(statlines['PTS']>=10) & (statlines['REB'] >= 10) & (statlines['AST']>=10)]
tripdubs
# Out:
#                   NAME TEAM        DATE  OPP  MINS  PTS  REB  AST  STL  BLK  \
# 76   Russell Westbrook  HOU  2020-01-15  POR    42   31   11   12    1    0
# 100  Russell Westbrook  HOU  2020-01-20  OKC    38   32   11   12    2    0
# 150  Russell Westbrook  WAS  2021-05-29  PHI    34   26   12   10    0    0
#
#      ...  3PM  3PA  FTM  FTA  dREB  oREB  TO  FLS  TFL  G
# 76   ...    2    5    7   12    10     1   1    1    1  1
# 100  ...    0    1    0    1     9     2   3    0    0  1
# 150  ...    3    6    5    5     9     3   3    4    0  1
#
# [3 rows x 23 columns]

# %%
russell = statlines[statlines['NAME']=='Russell Westbrook']
russ = ballers[ballers['NAME']=='Russell Westbrook']
russ
russell
# Out:
#                   NAME TEAM        DATE  OPP  MINS  PTS  REB  AST  STL  BLK  \
# 76   Russell Westbrook  HOU  2020-01-15  POR    42   31   11   12    1    0
# 100  Russell Westbrook  HOU  2020-01-20  OKC    38   32   11   12    2    0
# 150  Russell Westbrook  WAS  2021-05-29  PHI    34   26   12   10    0    0
# 204  Russell Westbrook  LAL  2021-11-02  HOU    37   27    9    7    1    0
# 228  Russell Westbrook  LAL  2021-11-04  OKC    35   27    6    5    0    0
# 282  Russell Westbrook  LAL  2023-02-07  OKC    28   27    4    8    2    1
# 334  Russell Westbrook  LAC  2023-03-18  ORL    37   14    5    9    1    0
# 361  Russell Westbrook  LAC  2023-03-21  OKC    26   15    8    2    2    1
#
#      ...  3PM  3PA  FTM  FTA  dREB  oREB  TO  FLS  TFL  G
# 76   ...    2    5    7   12    10     1   1    1    1  1
# 100  ...    0    1    0    1     9     2   3    0    0  1
# 150  ...    3    6    5    5     9     3   3    4    0  1
# 204  ...    0    4    7    8     4     5   3    1    0  1
# 228  ...    3    6    4    4     5     1   4    2    0  1
# 282  ...    4    7    3    6     4     0   6    1    0  1
# 334  ...    0    3    4    7     3     2   6    2    0  1
# 361  ...    0    3    3    5     5     3   2    4    0  1
#
# [8 rows x 23 columns]

# %%
hoopers = ['Russell Westbrook', 'Kevin Durant', 'LeBron James', 'Shai Gilgeous-Alexander']
#statlines[statlines['NAME'].isin(hoopers)].sort_values('PTS',ascending=False)
#ballers[ballers['NAME'].isin(hoopers)].sort_values('PTS',ascending=False)
#statlines.sort_values('PTS',ascending=False)
statlines.sort_values(by=['MINS'],ascending=False).head(10)
ballers.sort_values(by=['MINS'],ascending=False).head(10)
# Out:
#                         NAME  MINS  PTS  REB  AST  STL  BLK  FGM  FGA   FG%  \
# 137  Shai Gilgeous-Alexander   333  200   44   33   15    5   72  157  45.9
# 135        Russell Westbrook   277  199   66   65    9    2   77  151  51.0
# 100            Luguentz Dort   188   73   26    9    4    2   25   74  33.8
# 87               Josh Giddey   182   67   33   37    5    3   29   77  37.7
# 41             Darius Bazley   175   74   43    5    2    7   30   63  47.6
# 28                Chris Paul   173  100   30   29    5    4   34   67  50.7
# 48           Dennis Schroder   166   86   14   17    2    1   34   72  47.2
# 91          Kenrich Williams   153   46   30   15    4    1   18   39  46.2
# 54               Eric Gordon   119   37    5    8    0    1   14   45  31.1
# 124              Paul George   112   80   19   13    8    2   32   66  48.5
#
#      3PM  3PA  FTM  FTA  dREB  oREB  TO  FLS  TFL  G
# 137   11   30   45   50    39     5  27   24    0  9
# 135   12   35   33   48    49    17  28   15    1  8
# 100    8   40   15   17    15    11   7   18    0  6
# 87     2   14    7    9    28     5  14   10    1  6
# 41     9   24    5   11    37     6  17    6    0  8
# 28    15   31   17   20    29     1   8   12    1  5
# 48    12   34    6    7    14     0  13    9    0  5
# 91     5   15    5   10    22     8   7   14    0  6
# 54     9   29    0    1     4     1   2    8    0  4
# 124    7   20    9   12    18     1  12    9    0  3
